# %% [markdown]
# # Dragon Fruit Nutrient & Stress Decision Support
# Synthetic demonstration data only. Run from repository root.

# %%
from src.data_generation import generate_demo
from src.decision_support import classify_stress, nutrient_regression, anomaly_scores
df = generate_demo()
df.head()

# %%
stress_metrics, stress_importance, stress_predictions, cm = classify_stress(df)
nutrient_metrics, nutrient_importance, nutrient_predictions = nutrient_regression(df)
anomalies = anomaly_scores(df)
stress_metrics, nutrient_metrics
